# %% [markdown]
# <a href="https://colab.research.google.com/github/lukemckinstry/fastai-projects/blob/master/Democrats_Republicans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
dfolder = 'dem'
dfile = 'd.csv'

# %%
rfolder = 'rep'
rfile = 'r.csv'

# %%
# !ls '/content/'
# Out:
# adc.json  data	d.csv  k.csv  r.csv  sample_data  w.csv

# %% [markdown]
# You will need to run this line once per each category.

# %%
path = Path('data/party')
ddest = path/dfolder
rdest = path/rfolder
ddest.mkdir(parents=True, exist_ok=True)
rdest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('data/party/dem'), PosixPath('data/party/rep')]

# %% [markdown]
# ### Load csv from GoogleDrive

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
d_link = 'https://drive.google.com/open?id=1BnPhiVQKs0HoXxzVAsMelmrzzqH25oOq'
r_link = 'https://drive.google.com/open?id=15Sze1a9OCsMBIuMQThD6aHeh_B9mR0nR'

# %%
#fluff, id = wallaby_link.split('=')

did, rid = d_link.split('=')[1], r_link.split('=')[1] # Verify that you have everything after '='

# %%
wdownloaded = drive.CreateFile({'id':did}) 
wdownloaded.GetContentFile('d.csv')
kdownloaded = drive.CreateFile({'id':rid}) 
kdownloaded.GetContentFile('r.csv')

# %%
# !head -5  '/content/d.csv'
#!less w.csv
# Out:
# https://www.phila.gov/media/20171031123924/james-kenney-headshot.jpg
# http://www.philadelphiavotes.com/images/Lisa_Deeley.jpg
# http://www.philadelphiavotes.com/images/clark_headshot.png
# http://phlcouncil.com/wp-content/uploads/2016/01/DarrellClarke.jpg
# http://phlcouncil.com/wp-content/uploads/2016/01/MariaQSanchez-edit-1.jpg

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](https://github.com/fastai/course-v3/blob/master/nbs/dl1/images/download_images/upload.png?raw=1)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['dem','rep']

# %%
#?download_images
print(path/dfile, path/rfile)
print(ddest, rdest)
# Out:
# data/party/d.csv data/party/r.csv
# data/party/dem data/party/rep

# %%
#!ls '/content/data/aus-animals'
# !ls {ddest} | wc -l
# !ls {rdest} | wc -l
# Out:
# 991
# 997

# %%
# ?download_images

# %%
download_images(dfile, ddest, max_pics=1000)
download_images(rfile, rdest, max_pics=1000)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1000' class='' max='1000', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1000/1000 02:41<00:00]
#     </div>
# Error https://www.newhavenct.gov/images/BOA/17Jody_Ortiz_1.jpg HTTPSConnectionPool(host='www.newhavenct.gov', port=443): Max retries exceeded with url: /images/BOA/17Jody_Ortiz_1.jpg (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:847)'),))
# Error https://www.newhavenct.gov/images/BOA/7abigail_roth_1.jpg HTTPSConnectionPool(host='www.newhavenct.gov', port=443): Max retries exceeded with url: /images/BOA/7abigail_roth_1.jpg (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:847)'),))
# Error http://www.stamfordct.gov/sites/stamfordct/files/u358/david_martin1.jpg HTTPConnectionPool(host='www.stamfordct.gov', port=80): Max retries exceeded with url: /sites/stamfordct/files/u358/david_martin1.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7
gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000765.jpg'>
# Image data/party/rep/00000859.gif has 1 instead of 3 channels
# Image data/party/rep/00000439.png has 4 instead of 3 channels
# Image data/party/rep/00000515.jpg has 4 instead of 3 channels
# Image data/party/rep/00000852.gif has 1 instead of 3 channels
# Image data/party/rep/00000831.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000649.jpg'>
# Image data/party/rep/00000845.gif has 1 instead of 3 channels
# Image data/party/rep/00000848.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000758.jpg'>
# Image data/party/rep/00000834.gif has 1 instead of 3 channels
# Image data/party/rep/00000847.gif has 1 instead of 3 channels
# Image data/party/rep/00000858.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000001.jpg'>
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000041.png'>
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000002.jpg'>
# Image data/party/rep/00000856.gif has 1 instead of 3 channels
# Image data/party/rep/00000741.jpg has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000756.jpg'>
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000003.jpg'>
# Image data/party/rep/00000854.gif has 1 instead of 3 channels
# Image data/party/rep/00000841.gif has 1 instead of 3 channels
# Image data/party/rep/00000837.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000324.jpg'>
# Image data/party/rep/00000861.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000320.jpg'>
# Image data/party/rep/00000833.gif has 1 instead of 3 channels
# Image data/party/rep/00000849.gif has 1 instead of 3 channels
# Image data/party/rep/00000864.gif has 1 instead of 3 channels
# Image data/party/rep/00000868.gif has 1 instead of 3 channels
# Image data/party/rep/00000131.png has 4 instead of 3 channels
# Image data/party/rep/00000867.gif has 1 instead of 3 channels
# Image data/party/rep/00000857.gif has 1 instead of 3 channels
# Image data/party/rep/00000091.png has 1 instead of 3 channels
# Image data/party/rep/00000853.gif has 1 instead of 3 channels
# Image data/party/rep/00000855.gif has 1 instead of 3 channels
# Image data/party/rep/00000842.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000010.jpg'>
# Image data/party/rep/00000850.gif has 1 instead of 3 channels
# Image data/party/rep/00000838.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/party/rep/00000227.jpg'>

# %%
# !ls {ddest} | wc -l
# !ls {rdest} | wc -l
# Out:
# 961
# 950

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
# np.random.seed(42)
# data = ImageDataBunch.from_csv(".", folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
#         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['dem', 'rep']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['dem', 'rep'], 2, 1526, 381)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 69970894.65it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 02:12 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.884092</th>
#     <th>0.817924</th>
#     <th>0.314961</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.762699</th>
#     <th>0.615552</th>
#     <th>0.320210</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.659842</th>
#     <th>0.600359</th>
#     <th>0.291339</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.599219</th>
#     <th>0.588604</th>
#     <th>0.301837</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [3/5 01:43<01:08]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.503251</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.506612</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.613754</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='23', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.recorder.plot_losses()

# %%
learn.fit_one_cycle(4, max_lr=slice(3e-5,3e-4))
# Out:
# Total time: 02:32 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.529352</th>
#     <th>0.607406</th>
#     <th>0.293963</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.498151</th>
#     <th>0.612898</th>
#     <th>0.314961</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.428351</th>
#     <th>0.593771</th>
#     <th>0.288714</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.371480</th>
#     <th>0.588536</th>
#     <th>0.291339</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(10)
# Out:
# [('dem', 'rep', 60), ('rep', 'dem', 51)]

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
#len(idxs)
# ?ImageCleaner

# %%
ImageCleaner(ds, idxs, path)

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, duplicates=True)
# Out:
# 'No images to show :)'

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000021.jpg')
img
# Out:
# Image (3, 220, 300)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category black

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:13
# epoch  train_loss  valid_loss  error_rate
# 1      12.220007   1144188288.000000  0.765957    (00:13)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 01:07
# epoch  train_loss  valid_loss  error_rate
# 1      1.349151    1.062807    0.609929    (00:13)
# 2      1.373262    1.045115    0.546099    (00:13)
# 3      1.346169    1.006288    0.468085    (00:13)
# 4      1.334486    0.978713    0.453901    (00:13)
# 5      1.320978    0.978108    0.446809    (00:13)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.602823    0.119616    0.049645    (00:14)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 06:39
# epoch  train_loss  valid_loss  error_rate
# 1      1.513021    1.041628    0.507326    (00:13)
# 2      1.290093    0.994758    0.443223    (00:09)
# 3      1.185764    0.936145    0.410256    (00:09)
# 4      1.117229    0.838402    0.322344    (00:09)
# 5      1.022635    0.734872    0.252747    (00:09)
# 6      0.951374    0.627288    0.192308    (00:10)
# 7      0.916111    0.558621    0.184982    (00:09)
# 8      0.839068    0.503755    0.177656    (00:09)
# 9      0.749610    0.433475    0.144689    (00:09)
# 10     0.678583    0.367560    0.124542    (00:09)
# 11     0.615280    0.327029    0.100733    (00:10)
# 12     0.558776    0.298989    0.095238    (00:09)
# 13     0.518109    0.266998    0.084249    (00:09)
# 14     0.476290    0.257858    0.084249    (00:09)
# 15     0.436865    0.227299    0.067766    (00:09)
# 16     0.457189    0.236593    0.078755    (00:10)
# 17     0.420905    0.240185    0.080586    (00:10)
# 18     0.395686    0.255465    0.082418    (00:09)
# 19     0.373232    0.263469    0.080586    (00:09)
# 20     0.348988    0.258300    0.080586    (00:10)
# 21     0.324616    0.261346    0.080586    (00:09)
# 22     0.311310    0.236431    0.071429    (00:09)
# 23     0.328342    0.245841    0.069597    (00:10)
# 24     0.306411    0.235111    0.064103    (00:10)
# 25     0.289134    0.227465    0.069597    (00:09)
# 26     0.284814    0.226022    0.064103    (00:09)
# 27     0.268398    0.222791    0.067766    (00:09)
# 28     0.255431    0.227751    0.073260    (00:10)
# 29     0.240742    0.235949    0.071429    (00:09)
# 30     0.227140    0.225221    0.075092    (00:09)
# 31     0.213877    0.214789    0.069597    (00:09)
# 32     0.201631    0.209382    0.062271    (00:10)
# 33     0.189988    0.210684    0.065934    (00:09)
# 34     0.181293    0.214666    0.073260    (00:09)
# 35     0.184095    0.222575    0.073260    (00:09)
# 36     0.194615    0.229198    0.076923    (00:10)
# 37     0.186165    0.218206    0.075092    (00:09)
# 38     0.176623    0.207198    0.062271    (00:10)
# 39     0.166854    0.207256    0.065934    (00:10)
# 40     0.162692    0.206044    0.062271    (00:09)
